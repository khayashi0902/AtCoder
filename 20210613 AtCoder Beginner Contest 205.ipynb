# %%
n,k = (int(x) for x in input().split())

import numpy as np
a =np.array([int(x) for x in input().split()])

l =[int(x) for x in input().split()]

a = int(input())

xyp = [map(int, input().split()) for _ in range(n)]
x, y, p = [list(i) for i in zip(*xyp)]

import numpy as np
s = np.array([[c for c in input().strip()] for _ in range(h)])

cd = [tuple(map(int, input().split())) for _ in range(k)]

# %%
a,b = (int(x) for x in input().split())
print(a*(b/100))
# Out:
# 0.0

# %%
from collections import Counter
n = int(input())
a =[int(x) for x in input().split()]
c = Counter(a)
if c.most_common()[0][1] != 1:
    print("No")
else:
    print("Yes")

# %%
a,b,c = (int(x) for x in input().split())
if a > 0:
    if b > 0:
        if a>b:
            print(">")
        elif a == b:
            print("=")
        else:
            print("<")
    elif b == 0:
        print(">")
    else:
        if c%2 == 0:
            if abs(a) > abs(b):
                print(">")
            elif abs(a) == abs(b):
                print("=")
            else:
                print("<")
        else:
            print(">")
elif a == 0:
    if b > 0:
        print("<")
    elif b == 0:
        print("=")
    else:
        if c%2 == 0:
            print("<")
        else:
            print(">")
else:
    if b > 0:
        if c%2 == 0:
            if abs(a) > abs(b):
                print(">")
            elif abs(a) == abs(b):
                print("=")
            else:
                print("<")
        else:
            print("<")
    elif b == 0:
        if c%2 == 0:
            print(">")
        else:
            print("<")
    else:
        if c%2 == 0:
            if abs(a) > abs(b):
                print(">")
            elif abs(a) == abs(b):
                print("=")
            else:
                print("<")
        else:
            if abs(a) > abs(b):
                print("<")
            elif abs(a) == abs(b):
                print("=")
            else:
                print(">")

# %%
n,q = (int(x) for x in input().split())
a =[int(x) for x in input().split()]
k = [int(input()) for _ in range(q)]
d = {0:0}


def query(k):
    if k in d.keys():
        return d[k]
    ans = query(k-1)
    ans += 1
    while ans in a:
        ans += 1
    d[k] = ans
    return ans

for _ in range(q):
    k = int(input())
    if k in d.keys():
        print(d[k])
    else:
        ans = 
        while 
    print(query(k))

# %%
from collections import deque
# n,q = (int(x) for x in input().split())
# a = deque([int(x) for x in input().split()])
# K = [int(input()) for _ in range(q)]
n,q = 10**5, 10**5
a = deque([i for i in range(1,n+1)])
K = [i for i in range(1,q+1)]
d = {0:0}
max_k = max(K)
for i in range(1,max_k+1):
    ans = d[i-1] + 1
    while len(a) > 0 and ans == a[0]:
        a.popleft()
        ans += 1
    d[i] = ans

for k in K:
    print(d[k])

# %%
import numpy as np
# n,q = (int(x) for x in input().split())
# A = np.array([int(x) for x in input().split()])
# K = [int(input()) for _ in range(q)]
n,q = 10**5,10**5
A = np.array([i for i in range(1,n)])
K = [i for i in range(1,q)]

def plus_num(k):
    if 

for k in K:
    print(k+plus_num(k))

# %%
n,q = (int(x) for x in input().split())
A = [int(x) for x in input().split()]
K = [int(input()) for _ in range(q)]

C = [0]
aa = 1
for a in A:
    C.append(C[-1]+a-aa)
    aa = a+1

A = [0]+A

for k in K:
    if k>c[n]:
        print(k+n)
    else:
        right = n
        left = 1
        while True:
            middle = (left+right)//2
            if k<=c[middle-1]:
                right = middle-1
            elif k<=c[midlle]:
                break
            else:
                left = middle+1
        print(a[middle]-1-c[middle]+k)
